# %% [markdown]
# # ODE Exercises

# %%
# %pylab inline
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Question 1

# %% [markdown]
# For this question refer to the solutions for the simple pendulum we got using scipy's odeint from the beginning of the ODE Tour.
#
# (a) See what happens to the period of the pendulum as you change the initial angle of release. Plot θ vs t for 5 different initial angles, θ0 , spanning 0 to π. (i.e. 0, π/4 , π/2 , 3π/4 , and π ). Put them all on the same plot. What happens to the period of the pendulum as the initial angle increases from π/4 to 3π/4? What happens to the trajectory when the initial angle is 0 and π ?

# %%
def deriv(theta_current,t):  # return derivatives of the array theta
    g = 9.8 #m/s^2
    ell = 0.5 #m
    theta = theta_current[0]
    omega = theta_current[1]
    dtheta = omega
    domega = -(g/ell)*np.sin(theta)
    return np.array([ dtheta, domega ])

# %%
g = 9.8 #m/s^2
ell = 0.5 #m
t = np.arange(0.,50.+0.01,0.01)
omega0 = 0.
th0 = 0.*pi/180 # 0 degrees
th1 = 45.*pi/180 # 45 degrees
th2 = 90.*pi/180 # 90 degrees
th3 = 135.*pi/180 # 135 degrees
th4 = 180.*pi/180 # 180 degrees

theta_app = lambda t: th0*np.cos(np.sqrt(g/ell)*t)


theta_init0 = np.array([th0, omega0]) # initial values
theta_init1 = np.array([th1, omega0])
theta_init2 = np.array([th2, omega0])
theta_init3 = np.array([th3, omega0])
theta_init4 = np.array([th4, omega0])
theta0 = odeint(deriv,theta_init0,t)
theta1 = odeint(deriv,theta_init1,t)
theta2 = odeint(deriv,theta_init2,t)
theta3 = odeint(deriv,theta_init3,t)
theta4 = odeint(deriv,theta_init4,t)


plt.plot(t,theta0[:,0],label="0")
plt.plot(t,theta1[:,0],label="pi/4")
plt.plot(t,theta2[:,0],label="pi/2")
plt.plot(t,theta3[:,0],label="3pi/4")
plt.plot(t,theta4[:,0],label="pi")
plt.xlabel(r'$t (seconds)$',fontsize=20)
plt.ylabel(r'$\theta (rad)$',fontsize=20)
plt.ylim(-4.,4.)
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# (b) Make plots of θ vs. t, ω vs. t, and ω vs. θ (the so-called "phase plot") for θ0 = 0.95π. Look carefully at their behavior. What is going on in these figures?

# %%
g = 9.8 #m/s^2
ell = 0.5 #m
t = np.arange(0.,10.+0.01,0.01)
omega0 = 0.
th0 = np.pi
theta_app = lambda t: th0*np.cos(np.sqrt(g/ell)*t)


theta_init0 = np.array([th0, omega0]) # initial values

theta0 = odeint(deriv,theta_init0,t)


plt.plot(t,theta0[:,0],label="th0 = .95pi")
plt.title('theta vs time')
plt.xlabel(r'$t (seconds)$',fontsize=20)
plt.ylabel(r'$\theta (rad)$',fontsize=20)
plt.ylim(-4.,4.)
plt.grid()
plt.legend()
plt.show()

# %%
g = 9.8 #m/s^2
ell = 0.5 #m
t = np.arange(0.,10.+0.01,0.01)
omega0 = 0.
th0 = .95 * np.pi
theta_app = lambda t: th0*np.cos(np.sqrt(g/ell)*t)


theta_init0 = np.array([th0, omega0]) # initial values

theta0 = odeint(deriv,theta_init0,t)


plt.plot(t,theta0[:,1],label="th0 = .95pi")
plt.title('omega vs. time')
plt.xlabel(r'$t (seconds)$',fontsize=20)
plt.ylabel(r'$\omega (rad/sec)$',fontsize=20)
plt.ylim(-4.,4.)
plt.grid()
plt.legend()
plt.show()

# %%
g = 9.8 #m/s^2
ell = 0.5 #m
t = np.arange(0.,10.+0.01,0.01)
omega0 = 0.
th0 = .95 * np.pi
theta_app = lambda t: th0*np.cos(np.sqrt(g/ell)*t)


theta_init0 = np.array([th0, omega0]) # initial values

theta0 = odeint(deriv,theta_init0,t)


plt.plot(theta0[:,1],theta0[:,0], label="th0 = .95pi")
plt.title(r'$\omega\ vs.\ \theta$', fontsize=22)
plt.xlabel(r'$\theta (rad)$',fontsize=20)
plt.ylabel(r'$\omega (rad/sec)$',fontsize=20)
plt.ylim(-4.,4.)
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# (c) For the θ0 = 0.95π case, check that energy is conserved by plotting E/m vs. t (where E/m=gℓcos(θ)+0.5(ωℓ)^2).
#
# Is the energy a constant? If not, then the computational errors are producing a non-physical loss (or gain) of energy. Review the documentation for odeint and change the error tolerance value to a tighter number.

# %%
g = 9.8 #m/s^2
ell = 0.5 #m
t = np.arange(0.,10.01,0.01)
omega0 = 0.
th0 = .95 * np.pi
theta_app = lambda t: th0*np.cos(np.sqrt(g/ell)*t)
err = 9.49012e-16


theta_init0 = np.array([th0, omega0]) # initial values

theta0 = odeint(deriv,theta_init0,t, rtol = err, atol=1000*err)

Em = g * ell * (1-np.cos(theta0[:,0])) + .5 * (ell**2 * theta0[:,1]**2)

plt.plot(t,Em,label="E/m" )
plt.title(r'$E/m\ vs\ t$', fontsize=25)
plt.xlabel(r'$t (seconds)$',fontsize=20)
plt.ylabel(r'$\ E/m\ (joules/kg)$',fontsize=20)
plt.ylim(-5.,20.)
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# (d) Now look at what happens if we start the pendulum straight up, θ=π. Go for at least 50 s. Be sure to describe what happens numerically according to the θ vs. t, ω vs. t and E/m vs. t plots. What do you think should happen? What happens if you change the error tolerance on odeint? How does this compare to a nearly vertical pendulum: θ0=π−0.000001 ?

# %%
g = 9.8 #m/s^2
ell = 0.5 #m
t = np.arange(0.,50.+0.01,0.01)
omega0 = 0.
th0 = np.pi
theta_app = lambda t: th0*np.cos(np.sqrt(g/ell)*t)
err = 1.49012e-15

theta_init0 = np.array([th0, omega0]) # initial values

theta0 = odeint(deriv,theta_init0,t, rtol=err, atol = 1000*err)


plt.plot(t,theta0[:,0],label="th0 = pi")
plt.title('theta vs time')
plt.xlabel(r'$t (seconds)$',fontsize=20)
plt.ylabel(r'$\theta (rad)$',fontsize=20)
plt.ylim(-4.,4.)
plt.grid()
plt.legend()
plt.show()

plt.plot(theta0[:,1],theta0[:,0], label="th0 = pi")
plt.title(r'$\omega\ vs.\ \theta$', fontsize=22)
plt.xlabel(r'$\theta (rad)$',fontsize=20)
plt.ylabel(r'$\omega (rad/sec)$',fontsize=20)
plt.ylim(-4.,4.)
plt.grid()
plt.legend()
plt.show()

Em = g * ell * (1-np.cos(theta0[:,0])) + .5 * (ell**2 * theta0[:,1]**2)
plt.plot(t,Em,label="E/m")
plt.title('E/m vs t')
plt.xlabel(r'$t (seconds)$',fontsize=20)
plt.ylabel(r'$\ E/m\ (joules/kg)$',fontsize=20)
plt.xlim(0.,10.)
plt.grid()
plt.legend()
plt.show()

# %%
g = 9.8 #m/s^2
ell = 0.5 #m
t = np.arange(0.,50.+0.01,0.01)
omega0 = 0.
th0 = np.pi - .000001
theta_app = lambda t: th0*np.cos(np.sqrt(g/ell)*t)
err = 1.49012e-15

theta_init0 = np.array([th0, omega0]) # initial values

theta0 = odeint(deriv,theta_init0,t, rtol = err, atol=1000*err)


plt.plot(t,theta0[:,0],label="disturbed")
plt.title('theta vs time')
plt.xlabel(r'$t (seconds)$',fontsize=20)
plt.ylabel(r'$\theta (rad)$',fontsize=20)
plt.ylim(-4.,4.)
plt.grid()
plt.legend()
plt.show()

plt.plot(theta0[:,1],theta0[:,0], label="disturbed")
plt.title(r'$\omega\ vs.\ \theta$', fontsize=22)
plt.xlabel(r'$\theta (rad)$',fontsize=20)
plt.ylabel(r'$\omega (rad/sec)$',fontsize=20)
plt.ylim(-4.,4.)
plt.grid()
plt.legend()
plt.show()

Em = g * ell * (1-np.cos(theta0[:,0])) + .5 * (ell**2 * theta0[:,1]**2)

plt.plot(t,Em,label="E/m")
plt.title('E/m vs t')
plt.xlabel(r'$t (seconds)$',fontsize=20)
plt.ylabel(r'$\ E/m\ (joules/kg)$',fontsize=20)

plt.grid()
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: deriv() takes exactly 6 arguments (2 given)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: deriv() takes exactly 6 arguments (2 given)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: deriv() takes exactly 6 arguments (2 given)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: deriv() takes exactly 6 arguments (2 given)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: deriv() takes exactly 6 arguments (2 given)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: deriv() takes exactly 6 arguments (2 given)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: deriv() takes exactly 6 arguments (2 given)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: deriv() takes exactly 6 arguments (2 given)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: deriv() takes exactly 6 arguments (2 given)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: deriv() takes exactly 6 arguments (2 given)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: deriv() takes exactly 6 arguments (2 given)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: deriv() takes exactly 6 arguments (2 given)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: deriv() takes exactly 6 arguments (2 given)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: deriv() takes exactly 6 arguments (2 given)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: deriv() takes exactly 6 arguments (2 given)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: deriv() takes exactly 6 arguments (2 given)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: deriv() takes exactly 6 arguments (2 given)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: deriv() takes exactly 6 arguments (2 given)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: deriv() takes exactly 6 arguments (2 given)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: deriv() takes exactly 6 arguments (2 given)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: deriv() takes exactly 6 arguments (2 given)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: deriv() takes exactly 6 arguments (2 given)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: deriv() takes exactly 6 arguments (2 given)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: deriv() takes exactly 6 arguments (2 given)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: deriv() takes exactly 6 arguments (2 given)

# %% [markdown]
# ## Question 2

# %% [markdown]
# (a) Use Euler's method (not odeint) to solve the following first-order differential equation with given initial condition y(0) = 0.
#
# dy/dx = x - 2y
#
# Find the value of y when x = 1, y(1), using two different step sizes: 0.25 then 0.02.

# %%
def Euler(dt):
    tmax = 100 # maximum time
    nsteps = int(tmax/dt)
    t = np.zeros(nsteps)
    v = np.zeros(nsteps)
    y = np.zeros(nsteps)
 
    # set initial conditions, redundant in this example
    t[0] = 0.
    v[0] = 0.

    for i in range(len(t)-1):
        t[i+1] = t[i] + dt
        v[i+1] = t[i] + 2*y[i]
        y[i+1] = y[i] + dt * v[i]
        
    return t,v,y

t1,dydx1,y1 = Euler(.25)
t2, dydx2, y2 = Euler(.02)
ii = (t1 == 1)
jj = (t1 == 1)
print y1[ii]
print y2[jj]
# Out:
# [ 0.1875]
# [ 0.0012]

# %%
t1,dydx1,y1 = Euler(.25)
t2, dydx2, y2 = Euler(.02)
yexact = .25*np.exp(2*t2)-.5*t2-.25
plt.plot(t1,y1,label="dx=.25")
plt.plot(t2,y2,label="dx=.02")
plt.plot(t2,yexact,label="exact")
plt.xlabel(r'$ x $',fontsize=20)
plt.ylabel(r'$\ y $',fontsize=20)
plt.axis([0, 12, 0, 100])
plt.grid()
plt.legend()
plt.show()

# %%
def EulerCromer(dt):
    tmax = 100 # maximum time
    nsteps = int(tmax/dt)
    t = np.zeros(nsteps)
    v = np.zeros(nsteps)
    y = np.zeros(nsteps)
 
    # set initial conditions, redundant in this example
    t[0] = 0.
    v[0] = 0.
    for i in range(len(t)-1):
        t[i+1] = t[i] + dt
        v[i+1] = t[i] + 2*y[i]
        y[i+1] = y[i] + dt * v[i+1]
        
    return t,v,y

# %%
def Midpoint(dt):
    tmax = 100 # maximum time
    nsteps = int(tmax/dt)
    t = np.zeros(nsteps)
    v = np.zeros(nsteps)
    y = np.zeros(nsteps)
 
    # set initial conditions, redundant in this example
    t[0] = 0.
    v[0] = 0.

    for i in range(len(t)-1):
        t[i+1] = t[i] + dt
        v[i+1] = t[i] + 2*y[i]
        y[i+1] = y[i] + .5 * dt * (v[i] + v[i+1])
        
    return t,v,y

# %%
t1,dydx1,y1 = Euler(.25)
t2,dydx2,y2 = EulerCromer(.25)
t3,dydx3,y3 = Midpoint(.25)
t4, dydx4, y4 = Euler(.02)
t5, dydx5, y5 = EulerCromer(.02)
t6, dydx6, y6 = Midpoint(.02)
yexact1 = .25*np.exp(2*t1)-.5*t1+.25
yexact2 = .25*np.exp(2*t4)-.5*t4+.25

percentError1 = 100*abs( y1 - yexact1 ) / yexact1
percentError2 = 100*abs( y2 - yexact1 ) / yexact1
percentError3 = 100*abs( y3 - yexact1 ) / yexact1
percentError4 = 100*abs( y4 - yexact2 ) / yexact2
percentError5 = 100*abs( y5 - yexact2 ) / yexact2
percentError6 = 100*abs( y6 - yexact2 ) / yexact2

plt.semilogy(t1, percentError1, label='Euler (.25)')
plt.semilogy(t1, percentError2, label='EulerCromer (.25)')
plt.semilogy(t1, percentError3, label='Midpoint (.25)')
plt.semilogy(t4, percentError4, label='Euler (.02)')
plt.semilogy(t4, percentError5, label='EulerCromer (.02)')
plt.semilogy(t4, percentError6, label='Midpoint (.02)')

plt.axis([0, 10, 1, 100])
plt.xlabel("x",fontsize=20)
plt.ylabel("Percent Error (%)",fontsize=20)
plt.grid()
plt.legend(loc="lower right", fontsize=12)
plt.show()

# %% [markdown]
# ## Question 3

# %% [markdown]
# (a) Create a derivative function to solve this system of equations and use odeint to solve it for a projectile fired at an angle of 50 degrees from the horizontal at an initial speed of 30 m/s. Track the projectile's motion over the time interval of 0 to 200 seconds and let (x0,y0) = (0,0). You'll have to calculate (vx0,vy0) from the information provided. Let vter=44 m/s. Plot the trajectory of the projectile (y vs. x) to see how far it can travel in the x direction before landing.

# %%
def Proj_deriv(y,t):
    ay = -9.81 #g in m/s^2
    vx0 = y[0]
    vy0 = y[1]
    vterm = y[2]
    
    
    
    dvxdt = (ay*vx0/vterm**2) * np.sqrt(vy0**2 + vx0**2)
    dvydt = ay * (1 + (vy0/vterm**2) * np.sqrt(vy0**2 + vx0**2))

    return np.array([ dvxdt, dvydt ])
    

def Projectile(v0 = 30, th0 = 50*np.pi/180, time=200, vterm=44):

    
    t = np.arange(0.,time+0.001,0.001)

    #initial conditions
   
    vx0 = v0 * np.cos(th0)
    vy0 = v0 * np.sin(th0)
    x0 = 0
    y0 = 0
    init = np.array([vx0, vy0, vterm])

    #pass the function deriv to the solver with initial values and integration variable
    result = odeint(Proj_deriv, init ,t)

    vx = result[:,0]
    vy = result[:,1]
    print vx
    print vy
    x = vx * t
    y = vy * t
    plt.plot(x,y,label="Quadratic Drag")
    plt.xlabel("x")
    plt.ylabel("y(x)")
    plt.legend()
    plt.axis([0, 50, 0, 20])
    plt.show()
    
Projectile()
# Out:
# [  1.92836283e+01   1.92806977e+01   1.92777688e+01 ...,  -3.61023393e-11
#   -3.61019822e-11  -3.61016251e-11]
# [ 22.98133329  22.96803151  22.95473316 ..., -44.         -44.         -44.        ]

# %% [markdown]
# (b) Now create an interact object that uses sliders for the initial speed, terminal velocity, launch angle, and time. Have it plot two curves - one representing the solution with quadratic drag and the other in the absence of drag:

# %%
from IPython.html.widgets import interact, interactive

def Projectile(v0 = 30, th0 = 50*np.pi/180, time=200, vterm=44):

    
    t = np.arange(0.,time+0.001,0.001)

    #initial conditions
    vx0 = v0 * np.cos(th0)
    vy0 = v0 * np.sin(th0)
    x0 = 0
    y0 = 1.5
    init = np.array([vx0, vy0, vterm])

    #pass the function deriv to the solver with initial values and integration variable
    result = odeint(Proj_deriv, init ,t)

    vx = result[:,0]
    vy = result[:,1]
    x = vx * t
    y = vy * t
    xapp = x0 + vx0*t
    yapp = y0 + vy0*t - .5*9.81*t**2
    
    
    plt.plot(x,y,label="w/ Quadratic Drag")
    plt.plot(xapp,yapp,label="Approximate")
    plt.xlabel("x")
    plt.ylabel("y(x)")
    plt.legend()
    plt.axis([0, 80, 0, 200])
    plt.show()
    
v = interact(Projectile,v0=(0.,100.),th0=(0.*np.pi/180.,90*np.pi/180),time=(0,500),vterm=(20,150), full_output=1)

# %%
from IPython.display import HTML

s = """<table>
<tr>
<th>Projectile</th>
<th>Terminal Velocity (m/s)</th>
<th>Initial Height (m)</th>
<th>1st Pair</th>
<th>2nd Pair</th>
<th>3nd Pair</th>
</tr>
<tr>
<td>Golfball</td>
<td>44</td>
<td>0</td>
<td>70.1 m/s, 49.8 deg</td>
<td>81.6 m/s, 57.3 deg</td>
<td>81.6 m/s, 17.2 deg</td>
</tr>
<tr>
<td>Baseball</td>
<td>43</td>
<td>1.5</td>
<td>73.3 m/s, 49.8 deg</td>
<td>86.5 m/s, 57.3 deg</td>
<td>82.2 m/s, 17.2 deg</td>
</tr>
<tr>
<td>Pumpkin</td>
<td>107</td>
<td>1.5</td>
<td>43.1 m/s, 51.6 deg</td>
<td>54.0 m/s, 68.8 deg</td>
<td>63.0 m/s, 74.5 deg</td>
</tr>
</table>"""

h = HTML(s); h
# Out:
# <table>
# <tr>
# <th>Projectile</th>
# <th>Terminal Velocity (m/s)</th>
# <th>Initial Height (m)</th>
# <th>1st Pair</th>
# <th>2nd Pair</th>
# <th>3nd Pair</th>
# </tr>
# <tr>
# <td>Golfball</td>
# <td>44</td>
# <td>0</td>
# <td>70.1 m/s, 49.8 deg</td>
# <td>81.6 m/s, 57.3 deg</td>
# <td>81.6 m/s, 17.2 deg</td>
# </tr>
# <tr>
# <td>Baseball</td>
# <td>43</td>
# <td>1.5</td>
# <td>73.3 m/s, 49.8 deg</td>
# <td>86.5 m/s, 57.3 deg</td>
# <td>82.2 m/s, 17.2 deg</td>
# </tr>
# <tr>
# <td>Pumpkin</td>
# <td>107</td>
# <td>1.5</td>
# <td>43.1 m/s, 51.6 deg</td>
# <td>54.0 m/s, 68.8 deg</td>
# <td>63.0 m/s, 74.5 deg</td>
# </tr>
# </table>

# %% [markdown]
# (a) Write a function and interact widget that solves the ODE for the nonlinear pendulum with damping and driving. The parameters, ℓ, q, fd, and Ωd should be passed into the interact as sliders. Use initial values of θ0 =π/2, ω0=0 and a time span of 50 seconds.
#
# Check that the solution looks as it did before for the case: ℓ=1, q=0, fd=0, Ωd=0. Play with the sliders to see how the solution depends on the parameters.

# %%
def deriv(theta_current,t,ell,q,fd,Omega):  # return derivatives of the array theta

    g = 9.81
    omega0 = theta_current[0]
    theta0 = theta_current[1]
        
    dtheta = omega0
    domega = -(g/ell)*np.sin(theta0) - q*omega0 - fd*np.sin(Omega*t)
    
    return np.array([ domega, dtheta, omega0, theta0 ])

# %%
def NonlinearPendulum(omega = 0.0, th0 = np.pi/2, time=50, ell = 1.0, q = 0.0, fd = 0.0, Omega = 0.0):

    g = 9.81
    t = np.arange(0.,time+0.001,0.001)

    #initial conditions
    init = np.array([omega0, th0])

    #pass the function deriv to the solver with initial values and integration variable
    result = odeint(deriv, init ,t, args=(ell, q, fd, Omega))

    omega = result[:,0]
    theta = result[:,1]

    plt.plot(t,theta,label="With q=%f & Fd=%f"%(q, fd))
    plt.title(r'$\theta\ vs.\ time$', fontsize=22)
    plt.xlabel(r"$time$", fontsize=20)
    plt.ylabel(r'$\theta [rad]$', fontsize=20)
    plt.legend()
    plt.grid()
  #  plt.axis([0, 50, -10, 10])
    plt.show()
    
    plt.plot(t, omega, label="With q=%f & Fd=%f"%(q, fd))
    plt.title(r'$\omega\ vs.\ time$', fontsize=22)
    plt.xlabel(r"$time\ [sec]$",fontsize=20)
    plt.ylabel(r"$\omega\ [rad/sec]$",fontsize=20)
    plt.legend()
    plt.grid()
   # plt.axis([0, 50, -10, 10])
    plt.show()
    
    plt.plot(theta,omega, label="With q=%f & Fd=%f"%(q, fd))
    plt.title(r'$\omega\ vs.\ \theta$', fontsize=22)
    plt.xlabel(r'$\theta\ [rad]$',fontsize=20)
    plt.ylabel(r'$\omega\ [rad/sec]$',fontsize=20)
    #plt.ylim(-4.,4.)
    plt.grid()
    plt.legend()
    plt.show()

    Em = g * ell * (1-np.cos(theta)) + .5 * (ell**2 * omega**2)
    plt.plot(t,Em,label="With q=%f & Fd=%f"%(q, fd))
    plt.title(r'$E/m\ vs\ t$', fontsize=22)
    plt.xlabel(r'$time [sec]$',fontsize=20)
    plt.ylabel(r'$\ E/m\ [J/kg]$',fontsize=20)
    plt.xlim(0.,10.)
    #plt.ylim(-.5,.5)
    plt.grid()
    plt.legend()
    plt.show()
    
v = interact(NonlinearPendulum,ell=(0.,15.),q=(0.,10.),fd=(0.,10.),Omega=(0.,10.), full_output=1)

# %% [markdown]
# (b) Make static plots of θ vs. t, ω vs. t, E/m vs. t, and ω vs. θ for the ODE solution with
#
# - a damped oscillator, ℓ=9.8, q = 0.5, fd=0, Ωd=0
# - a driven + damped oscillator, ℓ=9.8, q=0.5, fd=0.2, Ωd=2./3
# - a chaotic pendulum, ℓ=9.8, q=0.5, fd=1.2, Ωd=2./3
#
# Include a legend with each plot. Do they look like you’d expect? Why or why not? Please explain what the results mean.

# %% [markdown]
# ### Damped Oscillator

# %%
NonlinearPendulum(omega = 0, th0 = np.pi/2, time=50, ell = 9.8, q = 0.5, fd = 0.0, Omega = 0.0)

# %% [markdown]
# ### Driven & Damped Oscillator

# %%
NonlinearPendulum(omega = 0, th0 = np.pi/2, time=50, ell = 9.8, q = 0.5, fd = 0.2, Omega = 2./3)

# %% [markdown]
# ### Chaotic Pendulum

# %%
NonlinearPendulum(omega = 0, th0 = np.pi/2, time=50, ell = 9.8, q = 0.5, fd = 1.2, Omega = 2./3)
